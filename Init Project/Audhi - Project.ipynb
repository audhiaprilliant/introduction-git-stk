# %% [markdown]
# ### Audhi's Project

# %%
# Data manipulation
import pandas as pd
# Matrix algebra
import numpy as np
# Data viz
import matplotlib.pyplot as plt

# %%
data_covid_indo = pd.read_csv('datasets/summary_covid19.txt')

# %%
data_covid_indo
# Out:
#                  date  confirmed  treated  deaths  recovered
# 2020/03/02  17:17 WIB          2        0       0        2.0
# 2020/03/03  17:17 WIB          2        0       0        2.0
# 2020/03/04  17:17 WIB          2        0       0        2.0
# 2020/03/05  17:17 WIB          2        0       0        2.0
# 2020/03/06  17:17 WIB          4        0       0        4.0
# ...               ...        ...      ...     ...        ...
# 2020/09/18  16:05 WIB     236519    56409    9336   170774.0
# 2020/09/19  15:22 WIB     240687    56889    9448   174350.0
# 2020/09/21  16:22 WIB     248852    58378    9677   180797.0
# 2020/09/22  15:51 WIB     252923    58788    9837   184298.0
# 2020/09/23  15:37 WIB     257388    59453    9977   187958.0
#
# [203 rows x 5 columns]

# %%
plt.
